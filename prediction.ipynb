# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
train=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\Datasets\covid_19_india.csv')
test=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\Datasets\StatewiseTestingDetails.csv')
train
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 7081  7082  07/10/20  8:00 AM            Telengana                       -
# 7082  7083  07/10/20  8:00 AM              Tripura                       -
# 7083  7084  07/10/20  8:00 AM          Uttarakhand                       -
# 7084  7085  07/10/20  8:00 AM        Uttar Pradesh                       -
# 7085  7086  07/10/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# ...

# %%
test
# Out:
#             Date                        State  TotalSamples Negative  Positive
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# ...          ...                          ...           ...      ...       ...
# 5961  2020-10-02                  West Bengal     3314598.0      NaN       NaN
# 5962  2020-10-03                  West Bengal     3355726.0      NaN       NaN
# 5963  2020-10-04                  West Bengal     3397988.0      NaN       NaN
# 5964  2020-10-05                  West Bengal     3438128.0      NaN       NaN
# 5965  2020-10-06                  West Bengal     3480510.0      NaN       NaN
#
# [5966 rows x 5 columns]

# %%
train.describe()
# Out:
#                Sno         Cured        Deaths     Confirmed
# count  7086.000000  7.086000e+03   7086.000000  7.086000e+03
# mean   3543.500000  3.423502e+04    836.188682  4.534495e+04
# std    2045.696336  9.913313e+04   2997.188810  1.263801e+05
# min       1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%    1772.250000  3.800000e+01      1.000000  1.660000e+02
# 50%    3543.500000  1.499500e+03     22.000000  2.774000e+03
# 75%    5314.750000  1.664325e+04    396.000000  2.573375e+04
# max    7086.000000  1.179726e+06  38717.000000  1.465911e+06

# %%
test.describe()
# Out:
#        TotalSamples      Positive
# count  5.966000e+03  4.494000e+03
# mean   7.168164e+05  2.798319e+04
# std    1.345531e+06  1.071249e+05
# min    5.800000e+01  0.000000e+00
# 25%    2.635500e+04  2.940000e+02
# 50%    1.413525e+05  2.256000e+03
# 75%    7.230415e+05  1.536500e+04
# max    1.104486e+07  1.465911e+06

# %%
corr=train.corr()
corr
# Out:
#                 Sno     Cured    Deaths  Confirmed
# Sno        1.000000  0.405672  0.283255   0.400772
# Cured      0.405672  1.000000  0.885666   0.993636
# Deaths     0.283255  0.885666  1.000000   0.917454
# Confirmed  0.400772  0.993636  0.917454   1.000000

# %%
corr=test.corr()
corr
# Out:
#               TotalSamples  Positive
# TotalSamples      1.000000  0.838116
# Positive          0.838116  1.000000

# %%
train.isnull()
# Out:
#         Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0     False  False  False                 False                    False
# 1     False  False  False                 False                    False
# 2     False  False  False                 False                    False
# 3     False  False  False                 False                    False
# 4     False  False  False                 False                    False
# ...     ...    ...    ...                   ...                      ...
# 7081  False  False  False                 False                    False
# 7082  False  False  False                 False                    False
# 7083  False  False  False                 False                    False
# 7084  False  False  False                 False                    False
# 7085  False  False  False                 False                    False
#
#       ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
test.isnull()
# Out:
#        Date  State  TotalSamples  Negative  Positive
# 0     False  False         False     False     False
# 1     False  False         False      True     False
# 2     False  False         False      True     False
# 3     False  False         False      True     False
# 4     False  False         False      True     False
# ...     ...    ...           ...       ...       ...
# 5961  False  False         False      True      True
# 5962  False  False         False      True      True
# 5963  False  False         False      True      True
# 5964  False  False         False      True      True
# 5965  False  False         False      True      True
#
# [5966 rows x 5 columns]

# %%
train.isna().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Date               0
# State              0
# TotalSamples       0
# Negative        2548
# Positive        1472
# dtype: int64

# %%
train.shape
# Out:
# (7086, 9)

# %%
test.shape
# Out:
# (5966, 5)

# %%
train['Cured'].interpolate(inplace=True)

# %%
train['Deaths'].interpolate(inplace=True)

# %%
test['Positive'].interpolate(inplace=True)

# %%
test['Negative'].interpolate(inplace=True)

# %%
train.Cured.value_counts()
# Out:
# 0         677
# 1         209
# 2          94
# 3          76
# 33         52
#          ...
# 3167        1
# 1118        1
# 13404       1
# 103504      1
# 6095        1
# Name: Cured, Length: 4232, dtype: int64

# %%
train.Deaths.value_counts()
# Out:
# 0       1620
# 1        457
# 2        218
# 3        194
# 4        121
#         ...
# 1321       1
# 1325       1
# 1345       1
# 1349       1
# 3936       1
# Name: Deaths, Length: 1739, dtype: int64

# %%
test.Positive.value_counts()
# Out:
# 1.000000         83
# 0.000000         77
# 2.000000         61
# 135596.000000    46
# 7.000000         40
#                  ..
# 121674.552632     1
# 173227.000000     1
# 2678.400000       1
# 468.200000        1
# 72718.000000      1
# Name: Positive, Length: 4658, dtype: int64

# %%
test.Negative.value_counts()
# Out:
# 26000     3
# 39008     3
# 14698     3
# 219       3
# 37004     3
#          ..
# 2091      1
# 220343    1
# 404852    1
# 814       1
# 10047     1
# Name: Negative, Length: 3357, dtype: int64

# %%
train['Cured'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7081    False
# 7082    False
# 7083    False
# 7084    False
# 7085    False
# Name: Cured, Length: 7086, dtype: bool

# %%
train['Deaths'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7081    False
# 7082    False
# 7083    False
# 7084    False
# 7085    False
# Name: Deaths, Length: 7086, dtype: bool

# %%
test['Positive'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5961    False
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# Name: Positive, Length: 5966, dtype: bool

# %%
test['Negative'].isnull()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5961     True
# 5962     True
# 5963     True
# 5964     True
# 5965     True
# Name: Negative, Length: 5966, dtype: bool

# %%
train.isnull().any()
# Out:
# Sno                         False
# Date                        False
# Time                        False
# State/UnionTerritory        False
# ConfirmedIndianNational     False
# ConfirmedForeignNational    False
# Cured                       False
# Deaths                      False
# Confirmed                   False
# dtype: bool

# %%
test.isnull().any()
# Out:
# Date            False
# State           False
# TotalSamples    False
# Negative         True
# Positive        False
# dtype: bool

# %%
numeric_features=train.select_dtypes(include=[np.number])
numeric_features.dtypes
corr=numeric_features.corr()
corr
# Out:
#                 Sno     Cured    Deaths  Confirmed
# Sno        1.000000  0.405672  0.283255   0.400772
# Cured      0.405672  1.000000  0.885666   0.993636
# Deaths     0.283255  0.885666  1.000000   0.917454
# Confirmed  0.400772  0.993636  0.917454   1.000000

# %%
numeric_features=test.select_dtypes(include=[np.number])
numeric_features.dtypes
corr=numeric_features.corr()
corr
# Out:
#               TotalSamples  Positive
# TotalSamples      1.000000  0.519832
# Positive          0.519832  1.000000

# %%
import pandas as pd
train=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\Datasets\covid_19_india.csv')
test=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\Datasets\StatewiseTestingDetails.csv')
train['source']='train'
test['source']='test'
predict=pd.concat([train,test],ignore_index=True)

# %%
predict
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1.0    30/01/20  6:00 PM               Kerala                       1
# 1      2.0    31/01/20  6:00 PM               Kerala                       1
# 2      3.0    01/02/20  6:00 PM               Kerala                       2
# 3      4.0    02/02/20  6:00 PM               Kerala                       3
# 4      5.0    03/02/20  6:00 PM               Kerala                       3
# ...    ...         ...      ...                  ...                     ...
# 13047  NaN  2020-10-02      NaN                  NaN                     NaN
# 13048  NaN  2020-10-03      NaN                  NaN                     NaN
# 13049  NaN  2020-10-04      NaN                  NaN                     NaN
# 13050  NaN  2020-10-05      NaN                  NaN                     NaN
# 13051  NaN  2020-10-06      NaN                  NaN                     NaN
#
# ...

# %%
predict.to_csv('predict.csv',index=False)
predict
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1.0    30/01/20  6:00 PM               Kerala                       1
# 1      2.0    31/01/20  6:00 PM               Kerala                       1
# 2      3.0    01/02/20  6:00 PM               Kerala                       2
# 3      4.0    02/02/20  6:00 PM               Kerala                       3
# 4      5.0    03/02/20  6:00 PM               Kerala                       3
# ...    ...         ...      ...                  ...                     ...
# 13047  NaN  2020-10-02      NaN                  NaN                     NaN
# 13048  NaN  2020-10-03      NaN                  NaN                     NaN
# 13049  NaN  2020-10-04      NaN                  NaN                     NaN
# 13050  NaN  2020-10-05      NaN                  NaN                     NaN
# 13051  NaN  2020-10-06      NaN                  NaN                     NaN
#
# ...

# %%
import pandas as pd
predict=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\predict.csv')
predict.groupby('State')['Cured'].sum()
# Out:
# State
# Andaman and Nicobar Islands                 0.0
# Andhra Pradesh                              0.0
# Arunachal Pradesh                           0.0
# Assam                                       0.0
# Bihar                                       0.0
# Chandigarh                                  0.0
# Chhattisgarh                                0.0
# Dadra and Nagar Haveli and Daman and Diu    0.0
# Delhi                                       0.0
# Goa                                         0.0
# Gujarat                                     0.0
# Haryana                                     0.0
# Himachal Pradesh                            0.0
# Jammu and Kashmir                           0.0
# Jharkhand                                   0.0
# Karnataka                                   0.0
# Kerala                                      0.0
# Ladakh                                      0.0
# Madhya Pradesh                              0.0
# ...

# %%
predict.groupby('State')['Cured'].mean()
# Out:
# State
# Andaman and Nicobar Islands                NaN
# Andhra Pradesh                             NaN
# Arunachal Pradesh                          NaN
# Assam                                      NaN
# Bihar                                      NaN
# Chandigarh                                 NaN
# Chhattisgarh                               NaN
# Dadra and Nagar Haveli and Daman and Diu   NaN
# Delhi                                      NaN
# Goa                                        NaN
# Gujarat                                    NaN
# Haryana                                    NaN
# Himachal Pradesh                           NaN
# Jammu and Kashmir                          NaN
# Jharkhand                                  NaN
# Karnataka                                  NaN
# Kerala                                     NaN
# Ladakh                                     NaN
# Madhya Pradesh                             NaN
# Maharashtra                                NaN
# ...

# %%
predict['Cured'].value_counts()
# Out:
# 0.0        677
# 1.0        209
# 2.0         94
# 3.0         76
# 33.0        52
#           ...
# 3232.0       1
# 1896.0       1
# 984.0        1
# 32384.0      1
# 55324.0      1
# Name: Cured, Length: 4232, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import datasets
from pylab import *
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import seaborn as sns;sns.set()
predict=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\predict.csv')
numeric_features=predict.select_dtypes(include=[np.number])
numeric_features.dtypes
corr=numeric_features.corr()
corr
# Out:
#                    Sno     Cured    Deaths  Confirmed  TotalSamples  Positive
# Sno           1.000000  0.405672  0.283255   0.400772           NaN       NaN
# Cured         0.405672  1.000000  0.885666   0.993636           NaN       NaN
# Deaths        0.283255  0.885666  1.000000   0.917454           NaN       NaN
# Confirmed     0.400772  0.993636  0.917454   1.000000           NaN       NaN
# TotalSamples       NaN       NaN       NaN        NaN      1.000000  0.838116
# Positive           NaN       NaN       NaN        NaN      0.838116  1.000000

# %%
sns.heatmap(predict.corr(), cmap="YlGnBu", annot = True)
plt.title('Confusion matrix of the classifier')
print(plt.title)
plt.xlabel('Predicted')
plt.ylabel('True')
print(plt.xlabel)
print(plt.ylabel)
plt.show()
# Out:
# <function title at 0x000001BA76FEB5E0>
# <function xlabel at 0x000001BA76FEB670>
# <function ylabel at 0x000001BA76FEB700>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns;sns.set()
from sklearn.model_selection import train_test_split
predict=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\predict.csv')
numeric_features=predict.select_dtypes(include=[np.number])
numeric_features.dtypes
plt.style.use('fivethirtyeight')
x=np.linspace(0.1,2*np.pi,41)
y=np.exp(np.sin(x))
sns.distplot(predict['Cured'],hist=True,kde=True,bins=int(200/5),color='darkblue',hist_kws={'edgecolor':'black'},kde_kws={'linewidth':'4'})
plt.title("Corona Prediction in India")
print("skew is:",predict.Cured.skew())
print("Kurtosis:%f" % predict.Cured.kurt())
plt.show()
# Out:
# skew is: 5.503804195503553
# Kurtosis:39.452909

# %%
predict.drop('Sno',axis=1,inplace=True)

# %%
predict=predict.sample(frac=1).reset_index(drop=True)

# %%
predict.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0    08/06/20  8:00 AM              Gujarat                       -
# 1  2020-07-20      NaN                  NaN                     NaN
# 2  2020-09-18      NaN                  NaN                     NaN
# 3    22/03/20  6:00 PM            Telengana                      11
# 4    23/09/20  8:00 AM                Delhi                       -
#
#   ConfirmedForeignNational     Cured  Deaths  Confirmed source  \
# 0                        -   13635.0  1249.0    20070.0  train
# 1                      NaN       NaN     NaN        NaN   test
# 2                      NaN       NaN     NaN        NaN   test
# 3                       11       1.0     0.0       22.0  train
# 4                        -  216401.0  5051.0   253075.0  train
#
#             State  TotalSamples Negative  Positive
# 0             NaN           NaN      NaN       NaN
# 1  Madhya Pradesh      615862.0   588491   23310.0
# ...

# %%
import pandas as pd
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
predict=pd.read_csv(r'C:\Users\balumani\Desktop\bala folder\Main\predict.csv')
plt.style.use('fivethirtyeight')
predict.plot(kind='hist',color='purple',figsize=(10,5))
plt.show()
